# %%
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tifffile import imsave

from sklearn.preprocessing import MinMaxScaler

# %%
TRAIN_DATASET_PATH ='C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'

# %%
test_image_flair = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_flair.nii').get_fdata()
test_image_flair.max()
# Out:
# 1854.603271484375

# %%
# Ölçekleyiciler 1D'ye uygulanır, bu nedenle yeniden şekillendirelim ve ardından orijinal şekline geri döndürelim.
scaler = MinMaxScaler()
test_image_flair=scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
# diğerleri içinde aynı işlemi yapıyoruz

test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1=scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce=scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2=scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()
test_mask=test_mask.astype(np.uint8)

# %%
np.unique(test_mask)  #0, 1, 2, 4 (0, 1, 2, 3 olarak ayarlamamız gerekiyor)
test_mask[test_mask==4] = 3

# %%
np.unique(test_mask)
# Out:
# array([0, 1, 2, 3], dtype=uint8)

# %%
import random
n_slice=random.randint(0, test_mask.shape[2])

plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.imshow(test_image_flair[:,:,n_slice], cmap='gray')
plt.title('Image flair')
plt.subplot(232)
plt.imshow(test_image_t1[:,:,n_slice], cmap='gray')
plt.title('Image t1')
plt.subplot(233)
plt.imshow(test_image_t1ce[:,:,n_slice], cmap='gray')
plt.title('Image t1ce')
plt.subplot(234)
plt.imshow(test_image_t2[:,:,n_slice], cmap='gray')
plt.title('Image t2')
plt.subplot(235)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
#T1ce, t2 ve flair'ı tek çok kanallı görüntüde birleştirin

combined_x = np.stack([test_image_flair, test_image_t1ce, test_image_t2], axis=3)
combined_x.shape
# Out:
# (240, 240, 155, 3)

# %%
# veriler için kırpma yapalım
combined_x=combined_x[56:184, 56:184, 13:141] #128x128x128x4

test_mask = test_mask[56:184, 56:184, 13:141]

# %%
n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(combined_x[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(combined_x[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(combined_x[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
imsave(TRAIN_DATASET_PATH + 'combined355.tif', combined_x)
np.save(TRAIN_DATASET_PATH + 'combined355.npy', combined_x)

# %%
my_img=np.load(TRAIN_DATASET_PATH + 'combined355.npy')
my_img.shape
# Out:
# (128, 128, 128, 3)

# %%
test_mask = to_categorical(test_mask, num_classes=4)

# %%
test_mask.shape
# Out:
# (128, 128, 128, 4)

# %%
# glob, verilen adrese ait belitrilen uzantıda ki tüm dosya adreslerini listede de tutar
t2_list = sorted(glob.glob(TRAIN_DATASET_PATH + '*/*t2.nii'))
t1ce_list = sorted(glob.glob(TRAIN_DATASET_PATH + '*/*t1ce.nii'))
flair_list = sorted(glob.glob(TRAIN_DATASET_PATH + '*/*flair.nii'))
mask_list = sorted(glob.glob(TRAIN_DATASET_PATH + '*/*seg.nii'))

# %%
t2_list
# Out:
# ['C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_001\\BraTS20_Training_001_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_002\\BraTS20_Training_002_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_003\\BraTS20_Training_003_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_004\\BraTS20_Training_004_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_005\\BraTS20_Training_005_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_006\\BraTS20_Training_006_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_007\\BraTS20_Training_007_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_008\\BraTS20_Training_008_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_009\\BraTS20_Training_009_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_010\\BraTS20_Training_010_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_011\\BraTS20_Training_011_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_012\\BraTS20_Training_012_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_013\\BraTS20_Training_013_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_014\\BraTS20_Training_014_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_015\\BraTS20_Training_015_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_016\\BraTS20_Training_016_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_017\\BraTS20_Training_017_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_018\\BraTS20_Training_018_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_019\\BraTS20_Training_019_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_020\\BraTS20_Training_020_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_021\\BraTS20_Training_021_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_022\\BraTS20_Training_022_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_023\\BraTS20_Training_023_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_024\\BraTS20_Training_024_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_025\\BraTS20_Training_025_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_026\\BraTS20_Training_026_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_027\\BraTS20_Training_027_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_028\\BraTS20_Training_028_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_029\\BraTS20_Training_029_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_030\\BraTS20_Training_030_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_031\\BraTS20_Training_031_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_032\\BraTS20_Training_032_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_033\\BraTS20_Training_033_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_034\\BraTS20_Training_034_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_035\\BraTS20_Training_035_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_036\\BraTS20_Training_036_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_037\\BraTS20_Training_037_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_038\\BraTS20_Training_038_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_039\\BraTS20_Training_039_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_040\\BraTS20_Training_040_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_041\\BraTS20_Training_041_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_042\\BraTS20_Training_042_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_043\\BraTS20_Training_043_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_044\\BraTS20_Training_044_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_045\\BraTS20_Training_045_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_046\\BraTS20_Training_046_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_047\\BraTS20_Training_047_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_048\\BraTS20_Training_048_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_049\\BraTS20_Training_049_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_050\\BraTS20_Training_050_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_051\\BraTS20_Training_051_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_052\\BraTS20_Training_052_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_053\\BraTS20_Training_053_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_054\\BraTS20_Training_054_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_055\\BraTS20_Training_055_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_056\\BraTS20_Training_056_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_057\\BraTS20_Training_057_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_058\\BraTS20_Training_058_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_059\\BraTS20_Training_059_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_060\\BraTS20_Training_060_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_061\\BraTS20_Training_061_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_062\\BraTS20_Training_062_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_063\\BraTS20_Training_063_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_064\\BraTS20_Training_064_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_065\\BraTS20_Training_065_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_066\\BraTS20_Training_066_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_067\\BraTS20_Training_067_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_068\\BraTS20_Training_068_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_069\\BraTS20_Training_069_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_070\\BraTS20_Training_070_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_071\\BraTS20_Training_071_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_072\\BraTS20_Training_072_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_073\\BraTS20_Training_073_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_074\\BraTS20_Training_074_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_075\\BraTS20_Training_075_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_076\\BraTS20_Training_076_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_077\\BraTS20_Training_077_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_078\\BraTS20_Training_078_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_079\\BraTS20_Training_079_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_080\\BraTS20_Training_080_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_081\\BraTS20_Training_081_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_082\\BraTS20_Training_082_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_083\\BraTS20_Training_083_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_084\\BraTS20_Training_084_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_085\\BraTS20_Training_085_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_086\\BraTS20_Training_086_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_087\\BraTS20_Training_087_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_088\\BraTS20_Training_088_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_089\\BraTS20_Training_089_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_090\\BraTS20_Training_090_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_091\\BraTS20_Training_091_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_092\\BraTS20_Training_092_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_093\\BraTS20_Training_093_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_094\\BraTS20_Training_094_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_095\\BraTS20_Training_095_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_096\\BraTS20_Training_096_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_097\\BraTS20_Training_097_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_098\\BraTS20_Training_098_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_099\\BraTS20_Training_099_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_100\\BraTS20_Training_100_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_101\\BraTS20_Training_101_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_102\\BraTS20_Training_102_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_103\\BraTS20_Training_103_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_104\\BraTS20_Training_104_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_105\\BraTS20_Training_105_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_106\\BraTS20_Training_106_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_107\\BraTS20_Training_107_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_108\\BraTS20_Training_108_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_109\\BraTS20_Training_109_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_110\\BraTS20_Training_110_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_111\\BraTS20_Training_111_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_112\\BraTS20_Training_112_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_113\\BraTS20_Training_113_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_114\\BraTS20_Training_114_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_115\\BraTS20_Training_115_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_116\\BraTS20_Training_116_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_117\\BraTS20_Training_117_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_118\\BraTS20_Training_118_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_119\\BraTS20_Training_119_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_120\\BraTS20_Training_120_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_121\\BraTS20_Training_121_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_122\\BraTS20_Training_122_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_123\\BraTS20_Training_123_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_124\\BraTS20_Training_124_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_125\\BraTS20_Training_125_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_126\\BraTS20_Training_126_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_127\\BraTS20_Training_127_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_128\\BraTS20_Training_128_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_129\\BraTS20_Training_129_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_130\\BraTS20_Training_130_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_131\\BraTS20_Training_131_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_132\\BraTS20_Training_132_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_133\\BraTS20_Training_133_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_134\\BraTS20_Training_134_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_135\\BraTS20_Training_135_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_136\\BraTS20_Training_136_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_137\\BraTS20_Training_137_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_138\\BraTS20_Training_138_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_139\\BraTS20_Training_139_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_140\\BraTS20_Training_140_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_141\\BraTS20_Training_141_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_142\\BraTS20_Training_142_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_143\\BraTS20_Training_143_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_144\\BraTS20_Training_144_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_145\\BraTS20_Training_145_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_146\\BraTS20_Training_146_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_147\\BraTS20_Training_147_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_148\\BraTS20_Training_148_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_149\\BraTS20_Training_149_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_150\\BraTS20_Training_150_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_151\\BraTS20_Training_151_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_152\\BraTS20_Training_152_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_153\\BraTS20_Training_153_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_154\\BraTS20_Training_154_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_155\\BraTS20_Training_155_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_156\\BraTS20_Training_156_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_157\\BraTS20_Training_157_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_158\\BraTS20_Training_158_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_159\\BraTS20_Training_159_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_160\\BraTS20_Training_160_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_161\\BraTS20_Training_161_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_162\\BraTS20_Training_162_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_163\\BraTS20_Training_163_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_164\\BraTS20_Training_164_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_165\\BraTS20_Training_165_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_166\\BraTS20_Training_166_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_167\\BraTS20_Training_167_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_168\\BraTS20_Training_168_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_169\\BraTS20_Training_169_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_170\\BraTS20_Training_170_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_171\\BraTS20_Training_171_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_172\\BraTS20_Training_172_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_173\\BraTS20_Training_173_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_174\\BraTS20_Training_174_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_175\\BraTS20_Training_175_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_176\\BraTS20_Training_176_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_177\\BraTS20_Training_177_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_178\\BraTS20_Training_178_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_179\\BraTS20_Training_179_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_180\\BraTS20_Training_180_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_181\\BraTS20_Training_181_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_182\\BraTS20_Training_182_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_183\\BraTS20_Training_183_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_184\\BraTS20_Training_184_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_185\\BraTS20_Training_185_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_186\\BraTS20_Training_186_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_187\\BraTS20_Training_187_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_188\\BraTS20_Training_188_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_189\\BraTS20_Training_189_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_190\\BraTS20_Training_190_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_191\\BraTS20_Training_191_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_192\\BraTS20_Training_192_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_193\\BraTS20_Training_193_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_194\\BraTS20_Training_194_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_195\\BraTS20_Training_195_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_196\\BraTS20_Training_196_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_197\\BraTS20_Training_197_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_198\\BraTS20_Training_198_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_199\\BraTS20_Training_199_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_200\\BraTS20_Training_200_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_201\\BraTS20_Training_201_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_202\\BraTS20_Training_202_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_203\\BraTS20_Training_203_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_204\\BraTS20_Training_204_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_205\\BraTS20_Training_205_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_206\\BraTS20_Training_206_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_207\\BraTS20_Training_207_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_208\\BraTS20_Training_208_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_209\\BraTS20_Training_209_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_210\\BraTS20_Training_210_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_211\\BraTS20_Training_211_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_212\\BraTS20_Training_212_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_213\\BraTS20_Training_213_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_214\\BraTS20_Training_214_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_215\\BraTS20_Training_215_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_216\\BraTS20_Training_216_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_217\\BraTS20_Training_217_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_218\\BraTS20_Training_218_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_219\\BraTS20_Training_219_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_220\\BraTS20_Training_220_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_221\\BraTS20_Training_221_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_222\\BraTS20_Training_222_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_223\\BraTS20_Training_223_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_224\\BraTS20_Training_224_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_225\\BraTS20_Training_225_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_226\\BraTS20_Training_226_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_227\\BraTS20_Training_227_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_228\\BraTS20_Training_228_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_229\\BraTS20_Training_229_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_230\\BraTS20_Training_230_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_231\\BraTS20_Training_231_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_232\\BraTS20_Training_232_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_233\\BraTS20_Training_233_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_234\\BraTS20_Training_234_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_235\\BraTS20_Training_235_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_236\\BraTS20_Training_236_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_237\\BraTS20_Training_237_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_238\\BraTS20_Training_238_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_239\\BraTS20_Training_239_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_240\\BraTS20_Training_240_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_241\\BraTS20_Training_241_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_242\\BraTS20_Training_242_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_243\\BraTS20_Training_243_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_244\\BraTS20_Training_244_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_245\\BraTS20_Training_245_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_246\\BraTS20_Training_246_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_247\\BraTS20_Training_247_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_248\\BraTS20_Training_248_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_249\\BraTS20_Training_249_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_250\\BraTS20_Training_250_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_251\\BraTS20_Training_251_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_252\\BraTS20_Training_252_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_253\\BraTS20_Training_253_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_254\\BraTS20_Training_254_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_255\\BraTS20_Training_255_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_256\\BraTS20_Training_256_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_257\\BraTS20_Training_257_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_258\\BraTS20_Training_258_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_259\\BraTS20_Training_259_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_260\\BraTS20_Training_260_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_261\\BraTS20_Training_261_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_262\\BraTS20_Training_262_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_263\\BraTS20_Training_263_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_264\\BraTS20_Training_264_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_265\\BraTS20_Training_265_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_266\\BraTS20_Training_266_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_267\\BraTS20_Training_267_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_268\\BraTS20_Training_268_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_269\\BraTS20_Training_269_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_270\\BraTS20_Training_270_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_271\\BraTS20_Training_271_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_272\\BraTS20_Training_272_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_273\\BraTS20_Training_273_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_274\\BraTS20_Training_274_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_275\\BraTS20_Training_275_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_276\\BraTS20_Training_276_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_277\\BraTS20_Training_277_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_278\\BraTS20_Training_278_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_279\\BraTS20_Training_279_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_280\\BraTS20_Training_280_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_281\\BraTS20_Training_281_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_282\\BraTS20_Training_282_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_283\\BraTS20_Training_283_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_284\\BraTS20_Training_284_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_285\\BraTS20_Training_285_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_286\\BraTS20_Training_286_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_287\\BraTS20_Training_287_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_288\\BraTS20_Training_288_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_289\\BraTS20_Training_289_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_290\\BraTS20_Training_290_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_291\\BraTS20_Training_291_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_292\\BraTS20_Training_292_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_293\\BraTS20_Training_293_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_294\\BraTS20_Training_294_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_295\\BraTS20_Training_295_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_296\\BraTS20_Training_296_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_297\\BraTS20_Training_297_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_298\\BraTS20_Training_298_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_299\\BraTS20_Training_299_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_300\\BraTS20_Training_300_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_301\\BraTS20_Training_301_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_302\\BraTS20_Training_302_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_303\\BraTS20_Training_303_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_304\\BraTS20_Training_304_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_305\\BraTS20_Training_305_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_306\\BraTS20_Training_306_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_307\\BraTS20_Training_307_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_308\\BraTS20_Training_308_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_309\\BraTS20_Training_309_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_310\\BraTS20_Training_310_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_311\\BraTS20_Training_311_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_312\\BraTS20_Training_312_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_313\\BraTS20_Training_313_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_314\\BraTS20_Training_314_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_315\\BraTS20_Training_315_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_316\\BraTS20_Training_316_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_317\\BraTS20_Training_317_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_318\\BraTS20_Training_318_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_319\\BraTS20_Training_319_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_320\\BraTS20_Training_320_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_321\\BraTS20_Training_321_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_322\\BraTS20_Training_322_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_323\\BraTS20_Training_323_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_324\\BraTS20_Training_324_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_325\\BraTS20_Training_325_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_326\\BraTS20_Training_326_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_327\\BraTS20_Training_327_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_328\\BraTS20_Training_328_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_329\\BraTS20_Training_329_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_330\\BraTS20_Training_330_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_331\\BraTS20_Training_331_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_332\\BraTS20_Training_332_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_333\\BraTS20_Training_333_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_334\\BraTS20_Training_334_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_335\\BraTS20_Training_335_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_336\\BraTS20_Training_336_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_337\\BraTS20_Training_337_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_338\\BraTS20_Training_338_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_339\\BraTS20_Training_339_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_340\\BraTS20_Training_340_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_341\\BraTS20_Training_341_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_342\\BraTS20_Training_342_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_343\\BraTS20_Training_343_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_344\\BraTS20_Training_344_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_345\\BraTS20_Training_345_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_346\\BraTS20_Training_346_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_347\\BraTS20_Training_347_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_348\\BraTS20_Training_348_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_349\\BraTS20_Training_349_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_350\\BraTS20_Training_350_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_351\\BraTS20_Training_351_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_352\\BraTS20_Training_352_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_353\\BraTS20_Training_353_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_354\\BraTS20_Training_354_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_355\\BraTS20_Training_355_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_356\\BraTS20_Training_356_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_357\\BraTS20_Training_357_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_358\\BraTS20_Training_358_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_359\\BraTS20_Training_359_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_360\\BraTS20_Training_360_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_361\\BraTS20_Training_361_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_362\\BraTS20_Training_362_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_363\\BraTS20_Training_363_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_364\\BraTS20_Training_364_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_365\\BraTS20_Training_365_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_366\\BraTS20_Training_366_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_367\\BraTS20_Training_367_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_368\\BraTS20_Training_368_t2.nii',
#  'C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData\\BraTS20_Training_369\\BraTS20_Training_369_t2.nii']

# %%
#üste veriyi incelemek için yaptığımız işlemi tüm verilerde yapalım

for img in range(len(t2_list)):   #Using t1_list as all lists are of same size
    print("Now preparing image and masks number: ", img)
      
    temp_image_t2=nib.load(t2_list[img]).get_fdata()
    temp_image_t2=scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)
   
    temp_image_t1ce=nib.load(t1ce_list[img]).get_fdata()
    temp_image_t1ce=scaler.fit_transform(temp_image_t1ce.reshape(-1, temp_image_t1ce.shape[-1])).reshape(temp_image_t1ce.shape)
   
    temp_image_flair=nib.load(flair_list[img]).get_fdata()
    temp_image_flair=scaler.fit_transform(temp_image_flair.reshape(-1, temp_image_flair.shape[-1])).reshape(temp_image_flair.shape)
        
    temp_mask=nib.load(mask_list[img]).get_fdata()
    temp_mask=temp_mask.astype(np.uint8)
    temp_mask[temp_mask==4] = 3  #Reassign mask values 4 to 3
    #print(np.unique(temp_mask))
    
    
    temp_combined_images = np.stack([temp_image_flair, temp_image_t1ce, temp_image_t2], axis=3)
    
    #Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches. 
    #cropping x, y, and z
    temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
    temp_mask = temp_mask[56:184, 56:184, 13:141]
    
    val, counts = np.unique(temp_mask, return_counts=True)
    
    if (1 - (counts[0]/counts.sum())) > 0.01:  #At least 1% useful volume with labels that are not 0
        print("Save Me")
        temp_mask= to_categorical(temp_mask, num_classes=4)
        np.save('C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/input_data_3channels/images/image_'+str(img)+'.npy', temp_combined_images)
        np.save('C:/Users/sibel/Downloads/archive/BraTS2020_TrainingData/input_data_3channels/masks/mask_'+str(img)+'.npy', temp_mask)
        
    else:
        print("I am useless")
# Out:
# Now preparing image and masks number:  0
# Save Me
# Now preparing image and masks number:  1
# Save Me
# Now preparing image and masks number:  2
# Save Me
# Now preparing image and masks number:  3
# Save Me
# Now preparing image and masks number:  4
# I am useless
# Now preparing image and masks number:  5
# Save Me
# Now preparing image and masks number:  6
# Save Me
# Now preparing image and masks number:  7
# Save Me
# Now preparing image and masks number:  8
# Save Me
# Now preparing image and masks number:  9
# Save Me
# Now preparing image and masks number:  10
# Save Me
# Now preparing image and masks number:  11
# Save Me
# Now preparing image and masks number:  12
# Save Me
# Now preparing image and masks number:  13
# Save Me
# Now preparing image and masks number:  14
# Save Me
# Now preparing image and masks number:  15
# Save Me
# Now preparing image and masks number:  16
# Save Me
# Now preparing image and masks number:  17
# Save Me
# Now preparing image and masks number:  18
# Save Me
# Now preparing image and masks number:  19
# Save Me
# Now preparing image and masks number:  20
# Save Me
# Now preparing image and masks number:  21
# Save Me
# Now preparing image and masks number:  22
# Save Me
# Now preparing image and masks number:  23
# Save Me
# Now preparing image and masks number:  24
# Save Me
# Now preparing image and masks number:  25
# Save Me
# Now preparing image and masks number:  26
# Save Me
# Now preparing image and masks number:  27
# I am useless
# Now preparing image and masks number:  28
# Save Me
# Now preparing image and masks number:  29
# Save Me
# Now preparing image and masks number:  30
# Save Me
# Now preparing image and masks number:  31
# Save Me
# Now preparing image and masks number:  32
# Save Me
# Now preparing image and masks number:  33
# Save Me
# Now preparing image and masks number:  34
# Save Me
# Now preparing image and masks number:  35
# I am useless
# Now preparing image and masks number:  36
# Save Me
# Now preparing image and masks number:  37
# Save Me
# Now preparing image and masks number:  38
# Save Me
# Now preparing image and masks number:  39
# Save Me
# Now preparing image and masks number:  40
# Save Me
# Now preparing image and masks number:  41
# Save Me
# Now preparing image and masks number:  42
# Save Me
# Now preparing image and masks number:  43
# I am useless
# Now preparing image and masks number:  44
# Save Me
# Now preparing image and masks number:  45
# Save Me
# Now preparing image and masks number:  46
# Save Me
# Now preparing image and masks number:  47
# Save Me
# Now preparing image and masks number:  48
# Save Me
# Now preparing image and masks number:  49
# Save Me
# Now preparing image and masks number:  50
# Save Me
# Now preparing image and masks number:  51
# Save Me
# Now preparing image and masks number:  52
# Save Me
# Now preparing image and masks number:  53
# Save Me
# Now preparing image and masks number:  54
# Save Me
# Now preparing image and masks number:  55
# Save Me
# Now preparing image and masks number:  56
# Save Me
# Now preparing image and masks number:  57
# Save Me
# Now preparing image and masks number:  58
# Save Me
# Now preparing image and masks number:  59
# Save Me
# Now preparing image and masks number:  60
# I am useless
# Now preparing image and masks number:  61
# Save Me
# Now preparing image and masks number:  62
# I am useless
# Now preparing image and masks number:  63
# Save Me
# Now preparing image and masks number:  64
# Save Me
# Now preparing image and masks number:  65
# Save Me
# Now preparing image and masks number:  66
# Save Me
# Now preparing image and masks number:  67
# Save Me
# Now preparing image and masks number:  68
# Save Me
# Now preparing image and masks number:  69
# Save Me
# Now preparing image and masks number:  70
# Save Me
# Now preparing image and masks number:  71
# Save Me
# Now preparing image and masks number:  72
# Save Me
# Now preparing image and masks number:  73
# Save Me
# Now preparing image and masks number:  74
# Save Me
# Now preparing image and masks number:  75
# Save Me
# Now preparing image and masks number:  76
# Save Me
# Now preparing image and masks number:  77
# Save Me
# Now preparing image and masks number:  78
# I am useless
# Now preparing image and masks number:  79
# Save Me
# Now preparing image and masks number:  80
# Save Me
# Now preparing image and masks number:  81
# I am useless
# Now preparing image and masks number:  82
# Save Me
# Now preparing image and masks number:  83
# Save Me
# Now preparing image and masks number:  84
# Save Me
# Now preparing image and masks number:  85
# I am useless
# Now preparing image and masks number:  86
# Save Me
# Now preparing image and masks number:  87
# Save Me
# Now preparing image and masks number:  88
# Save Me
# Now preparing image and masks number:  89
# Save Me
# Now preparing image and masks number:  90
# Save Me
# Now preparing image and masks number:  91
# Save Me
# Now preparing image and masks number:  92
# Save Me
# Now preparing image and masks number:  93
# Save Me
# Now preparing image and masks number:  94
# Save Me
# Now preparing image and masks number:  95
# Save Me
# Now preparing image and masks number:  96
# Save Me
# Now preparing image and masks number:  97
# Save Me
# Now preparing image and masks number:  98
# I am useless
# Now preparing image and masks number:  99
# Save Me
# Now preparing image and masks number:  100
# Save Me
# Now preparing image and masks number:  101
# Save Me
# Now preparing image and masks number:  102
# Save Me
# Now preparing image and masks number:  103
# Save Me
# Now preparing image and masks number:  104
# Save Me
# Now preparing image and masks number:  105
# Save Me
# Now preparing image and masks number:  106
# Save Me
# Now preparing image and masks number:  107
# I am useless
# Now preparing image and masks number:  108
# Save Me
# Now preparing image and masks number:  109
# I am useless
# Now preparing image and masks number:  110
# Save Me
# Now preparing image and masks number:  111
# Save Me
# Now preparing image and masks number:  112
# Save Me
# Now preparing image and masks number:  113
# Save Me
# Now preparing image and masks number:  114
# Save Me
# Now preparing image and masks number:  115
# Save Me
# Now preparing image and masks number:  116
# Save Me
# Now preparing image and masks number:  117
# Save Me
# Now preparing image and masks number:  118
# Save Me
# Now preparing image and masks number:  119
# Save Me
# Now preparing image and masks number:  120
# Save Me
# Now preparing image and masks number:  121
# I am useless
# Now preparing image and masks number:  122
# Save Me
# Now preparing image and masks number:  123
# Save Me
# Now preparing image and masks number:  124
# Save Me
# Now preparing image and masks number:  125
# Save Me
# Now preparing image and masks number:  126
# Save Me
# Now preparing image and masks number:  127
# Save Me
# Now preparing image and masks number:  128
# Save Me
# Now preparing image and masks number:  129
# Save Me
# Now preparing image and masks number:  130
# Save Me
# Now preparing image and masks number:  131
# Save Me
# Now preparing image and masks number:  132
# Save Me
# Now preparing image and masks number:  133
# Save Me
# Now preparing image and masks number:  134
# Save Me
# Now preparing image and masks number:  135
# Save Me
# Now preparing image and masks number:  136
# Save Me
# Now preparing image and masks number:  137
# Save Me
# Now preparing image and masks number:  138
# I am useless
# Now preparing image and masks number:  139
# Save Me
# Now preparing image and masks number:  140
# Save Me
# Now preparing image and masks number:  141
# I am useless
# Now preparing image and masks number:  142
# Save Me
# Now preparing image and masks number:  143
# Save Me
# Now preparing image and masks number:  144
# Save Me
# Now preparing image and masks number:  145
# Save Me
# Now preparing image and masks number:  146
# Save Me
# Now preparing image and masks number:  147
# Save Me
# Now preparing image and masks number:  148
# Save Me
# Now preparing image and masks number:  149
# Save Me
# Now preparing image and masks number:  150
# Save Me
# Now preparing image and masks number:  151
# Save Me
# Now preparing image and masks number:  152
# Save Me
# Now preparing image and masks number:  153
# Save Me
# Now preparing image and masks number:  154
# Save Me
# Now preparing image and masks number:  155
# Save Me
# Now preparing image and masks number:  156
# Save Me
# Now preparing image and masks number:  157
# Save Me
# Now preparing image and masks number:  158
# Save Me
# Now preparing image and masks number:  159
# Save Me
# Now preparing image and masks number:  160
# Save Me
# Now preparing image and masks number:  161
# Save Me
# Now preparing image and masks number:  162
# Save Me
# Now preparing image and masks number:  163
# Save Me
# Now preparing image and masks number:  164
# Save Me
# Now preparing image and masks number:  165
# Save Me
# Now preparing image and masks number:  166
# Save Me
# Now preparing image and masks number:  167
# Save Me
# Now preparing image and masks number:  168
# Save Me
# Now preparing image and masks number:  169
# Save Me
# Now preparing image and masks number:  170
# Save Me
# Now preparing image and masks number:  171
# Save Me
# Now preparing image and masks number:  172
# Save Me
# Now preparing image and masks number:  173
# Save Me
# Now preparing image and masks number:  174
# Save Me
# Now preparing image and masks number:  175
# Save Me
# Now preparing image and masks number:  176
# I am useless
# Now preparing image and masks number:  177
# Save Me
# Now preparing image and masks number:  178
# Save Me
# Now preparing image and masks number:  179
# Save Me
# Now preparing image and masks number:  180
# Save Me
# Now preparing image and masks number:  181
# Save Me
# Now preparing image and masks number:  182
# Save Me
# Now preparing image and masks number:  183
# Save Me
# Now preparing image and masks number:  184
# Save Me
# Now preparing image and masks number:  185
# Save Me
# Now preparing image and masks number:  186
# Save Me
# Now preparing image and masks number:  187
# Save Me
# Now preparing image and masks number:  188
# Save Me
# Now preparing image and masks number:  189
# Save Me
# Now preparing image and masks number:  190
# Save Me
# Now preparing image and masks number:  191
# Save Me
# Now preparing image and masks number:  192
# Save Me
# Now preparing image and masks number:  193
# Save Me
# Now preparing image and masks number:  194
# Save Me
# Now preparing image and masks number:  195
# Save Me
# Now preparing image and masks number:  196
# Save Me
# Now preparing image and masks number:  197
# Save Me
# Now preparing image and masks number:  198
# Save Me
# Now preparing image and masks number:  199
# Save Me
# Now preparing image and masks number:  200
# Save Me
# Now preparing image and masks number:  201
# Save Me
# Now preparing image and masks number:  202
# Save Me
# Now preparing image and masks number:  203
# I am useless
# Now preparing image and masks number:  204
# Save Me
# Now preparing image and masks number:  205
# Save Me
# Now preparing image and masks number:  206
# Save Me
# Now preparing image and masks number:  207
# Save Me
# Now preparing image and masks number:  208
# Save Me
# Now preparing image and masks number:  209
# Save Me
# Now preparing image and masks number:  210
# Save Me
# Now preparing image and masks number:  211
# Save Me
# Now preparing image and masks number:  212
# Save Me
# Now preparing image and masks number:  213
# Save Me
# Now preparing image and masks number:  214
# Save Me
# Now preparing image and masks number:  215
# Save Me
# Now preparing image and masks number:  216
# I am useless
# Now preparing image and masks number:  217
# Save Me
# Now preparing image and masks number:  218
# Save Me
# Now preparing image and masks number:  219
# Save Me
# Now preparing image and masks number:  220
# Save Me
# Now preparing image and masks number:  221
# Save Me
# Now preparing image and masks number:  222
# Save Me
# Now preparing image and masks number:  223
# Save Me
# Now preparing image and masks number:  224
# Save Me
# Now preparing image and masks number:  225
# Save Me
# Now preparing image and masks number:  226
# Save Me
# Now preparing image and masks number:  227
# Save Me
# Now preparing image and masks number:  228
# Save Me
# Now preparing image and masks number:  229
# Save Me
# Now preparing image and masks number:  230
# Save Me
# Now preparing image and masks number:  231
# Save Me
# Now preparing image and masks number:  232
# I am useless
# Now preparing image and masks number:  233
# Save Me
# Now preparing image and masks number:  234
# Save Me
# Now preparing image and masks number:  235
# Save Me
# Now preparing image and masks number:  236
# Save Me
# Now preparing image and masks number:  237
# Save Me
# Now preparing image and masks number:  238
# Save Me
# Now preparing image and masks number:  239
# Save Me
# Now preparing image and masks number:  240
# Save Me
# Now preparing image and masks number:  241
# Save Me
# Now preparing image and masks number:  242
# Save Me
# Now preparing image and masks number:  243
# Save Me
# Now preparing image and masks number:  244
# Save Me
# Now preparing image and masks number:  245
# Save Me
# Now preparing image and masks number:  246
# Save Me
# Now preparing image and masks number:  247
# Save Me
# Now preparing image and masks number:  248
# Save Me
# Now preparing image and masks number:  249
# Save Me
# Now preparing image and masks number:  250
# Save Me
# Now preparing image and masks number:  251
# Save Me
# Now preparing image and masks number:  252
# Save Me
# Now preparing image and masks number:  253
# Save Me
# Now preparing image and masks number:  254
# Save Me
# Now preparing image and masks number:  255
# Save Me
# Now preparing image and masks number:  256
# Save Me
# Now preparing image and masks number:  257
# Save Me
# Now preparing image and masks number:  258
# Save Me
# Now preparing image and masks number:  259
# Save Me
# Now preparing image and masks number:  260
# Save Me
# Now preparing image and masks number:  261
# Save Me
# Now preparing image and masks number:  262
# Save Me
# Now preparing image and masks number:  263
# Save Me
# Now preparing image and masks number:  264
# Save Me
# Now preparing image and masks number:  265
# Save Me
# Now preparing image and masks number:  266
# Save Me
# Now preparing image and masks number:  267
# I am useless
# Now preparing image and masks number:  268
# Save Me
# Now preparing image and masks number:  269
# Save Me
# Now preparing image and masks number:  270
# Save Me
# Now preparing image and masks number:  271
# Save Me
# Now preparing image and masks number:  272
# Save Me
# Now preparing image and masks number:  273
# Save Me
# Now preparing image and masks number:  274
# Save Me
# Now preparing image and masks number:  275
# Save Me
# Now preparing image and masks number:  276
# I am useless
# Now preparing image and masks number:  277
# Save Me
# Now preparing image and masks number:  278
# Save Me
# Now preparing image and masks number:  279
# Save Me
# Now preparing image and masks number:  280
# Save Me
# Now preparing image and masks number:  281
# Save Me
# Now preparing image and masks number:  282
# Save Me
# Now preparing image and masks number:  283
# Save Me
# Now preparing image and masks number:  284
# Save Me
# Now preparing image and masks number:  285
# Save Me
# Now preparing image and masks number:  286
# Save Me
# Now preparing image and masks number:  287
# Save Me
# Now preparing image and masks number:  288
# Save Me
# Now preparing image and masks number:  289
# Save Me
# Now preparing image and masks number:  290
# Save Me
# Now preparing image and masks number:  291
# Save Me
# Now preparing image and masks number:  292
# Save Me
# Now preparing image and masks number:  293
# Save Me
# Now preparing image and masks number:  294
# Save Me
# Now preparing image and masks number:  295
# Save Me
# Now preparing image and masks number:  296
# Save Me
# Now preparing image and masks number:  297
# Save Me
# Now preparing image and masks number:  298
# Save Me
# Now preparing image and masks number:  299
# Save Me
# Now preparing image and masks number:  300
# Save Me
# Now preparing image and masks number:  301
# Save Me
# Now preparing image and masks number:  302
# Save Me
# Now preparing image and masks number:  303
# Save Me
# Now preparing image and masks number:  304
# Save Me
# Now preparing image and masks number:  305
# Save Me
# Now preparing image and masks number:  306
# Save Me
# Now preparing image and masks number:  307
# Save Me
# Now preparing image and masks number:  308
# Save Me
# Now preparing image and masks number:  309
# Save Me
# Now preparing image and masks number:  310
# Save Me
# Now preparing image and masks number:  311
# Save Me
# Now preparing image and masks number:  312
# Save Me
# Now preparing image and masks number:  313
# I am useless
# Now preparing image and masks number:  314
# Save Me
# Now preparing image and masks number:  315
# Save Me
# Now preparing image and masks number:  316
# I am useless
# Now preparing image and masks number:  317
# Save Me
# Now preparing image and masks number:  318
# Save Me
# Now preparing image and masks number:  319
# Save Me
# Now preparing image and masks number:  320
# Save Me
# Now preparing image and masks number:  321
# Save Me
# Now preparing image and masks number:  322
# Save Me
# Now preparing image and masks number:  323
# Save Me
# Now preparing image and masks number:  324
# I am useless
# Now preparing image and masks number:  325
# Save Me
# Now preparing image and masks number:  326
# Save Me
# Now preparing image and masks number:  327
# Save Me
# Now preparing image and masks number:  328
# Save Me
# Now preparing image and masks number:  329
# Save Me
# Now preparing image and masks number:  330
# Save Me
# Now preparing image and masks number:  331
# Save Me
# Now preparing image and masks number:  332
# Save Me
# Now preparing image and masks number:  333
# Save Me
# Now preparing image and masks number:  334
# Save Me
# Now preparing image and masks number:  335
# Save Me
# Now preparing image and masks number:  336
# Save Me
# Now preparing image and masks number:  337
# Save Me
# Now preparing image and masks number:  338
# Save Me
# Now preparing image and masks number:  339
# Save Me
# Now preparing image and masks number:  340
# I am useless
# Now preparing image and masks number:  341
# Save Me
# Now preparing image and masks number:  342
# Save Me
# Now preparing image and masks number:  343
# Save Me
# Now preparing image and masks number:  344
# Save Me
# Now preparing image and masks number:  345
# Save Me
# Now preparing image and masks number:  346
# Save Me
# Now preparing image and masks number:  347
# Save Me
# Now preparing image and masks number:  348
# Save Me
# Now preparing image and masks number:  349
# Save Me
# Now preparing image and masks number:  350
# Save Me
# Now preparing image and masks number:  351
# Save Me
# Now preparing image and masks number:  352
# Save Me
# Now preparing image and masks number:  353
# Save Me
# Now preparing image and masks number:  354
# Save Me
# Now preparing image and masks number:  355
# Save Me
# Now preparing image and masks number:  356
# Save Me
# Now preparing image and masks number:  357
# Save Me
# Now preparing image and masks number:  358
# Save Me
# Now preparing image and masks number:  359
# Save Me
# Now preparing image and masks number:  360
# Save Me
# Now preparing image and masks number:  361
# Save Me
# Now preparing image and masks number:  362
# Save Me
# Now preparing image and masks number:  363
# Save Me
# Now preparing image and masks number:  364
# Save Me
# Now preparing image and masks number:  365
# Save Me
# Now preparing image and masks number:  366
# Save Me
# Now preparing image and masks number:  367
# Save Me
# Now preparing image and masks number:  368
# Save Me

# %%
import splitfolders

input_folder = 'D:/archive/BraTS2020_TrainingData/input_data_3channels/'
output_folder = 'D:/archive/BraTS2020_TrainingData/input_data_128/'

splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None) # default values
# Out:
# Copying files: 0 files [00:00, ? files/s]
#
#
# Copying files: 1 files [00:01,  1.66s/ files]
#
#
# Copying files: 2 files [00:02,  1.21s/ files]
#
#
# Copying files: 3 files [00:03,  1.01 files/s]
#
#
# Copying files: 4 files [00:04,  1.01 files/s]
#
#
# Copying files: 5 files [00:05,  1.02 files/s]
#
#
# Copying files: 6 files [00:06,  1.01 files/s]
#
#
# Copying files: 7 files [00:07,  1.00s/ files]
#
#
# Copying files: 8 files [00:08,  1.05s/ files]
#
#
# Copying files: 9 files [00:10,  1.29s/ files]
#
#
# Copying files: 10 files [00:12,  1.46s/ files]
#
#
# Copying files: 11 files [00:13,  1.49s/ files]
#
#
# Copying files: 12 files [00:15,  1.56s/ files]
#
#
# Copying files: 13 files [00:17,  1.62s/ files]
#
#
# Copying files: 14 files [00:18,  1.62s/ files]
#
#
# Copying files: 15 files [00:20,  1.62s/ files]
#
#
# Copying files: 16 files [00:22,  1.64s/ files]
#
#
# Copying files: 17 files [00:23,  1.51s/ files]
#
#
# Copying files: 18 files [00:25,  1.60s/ files]
#
#
# Copying files: 19 files [00:27,  1.81s/ files]
#
#
# Copying files: 20 files [00:28,  1.74s/ files]
#
#
# Copying files: 21 files [00:30,  1.70s/ files]
#
#
# Copying files: 22 files [00:32,  1.85s/ files]
#
#
# Copying files: 23 files [00:34,  1.80s/ files]
#
#
# Copying files: 24 files [00:36,  1.81s/ files]
#
#
# Copying files: 25 files [00:38,  1.81s/ files]
#
#
# Copying files: 26 files [00:39,  1.78s/ files]
#
#
# Copying files: 27 files [00:41,  1.74s/ files]
#
#
# Copying files: 28 files [00:43,  1.92s/ files]
#
#
# Copying files: 29 files [00:45,  1.86s/ files]
#
#
# Copying files: 30 files [00:47,  1.79s/ files]
#
#
# Copying files: 31 files [00:48,  1.72s/ files]
#
#
# Copying files: 32 files [00:50,  1.82s/ files]
#
#
# Copying files: 33 files [00:52,  1.68s/ files]
#
#
# Copying files: 34 files [00:53,  1.59s/ files]
#
#
# Copying files: 35 files [00:55,  1.72s/ files]
#
#
# Copying files: 36 files [00:57,  1.74s/ files]
#
#
# Copying files: 37 files [00:58,  1.64s/ files]
#
#
# Copying files: 38 files [01:00,  1.58s/ files]
#
#
# Copying files: 39 files [01:02,  1.86s/ files]
#
#
# Copying files: 40 files [01:03,  1.54s/ files]
#
#
# Copying files: 41 files [01:05,  1.64s/ files]
#
#
# Copying files: 42 files [01:07,  1.71s/ files]
#
#
# Copying files: 43 files [01:09,  1.81s/ files]
#
#
# Copying files: 44 files [01:11,  1.82s/ files]
#
#
# Copying files: 45 files [01:13,  2.12s/ files]
#
#
# Copying files: 46 files [01:15,  1.95s/ files]
#
#
# Copying files: 47 files [01:16,  1.79s/ files]
#
#
# Copying files: 48 files [01:18,  1.80s/ files]
#
#
# Copying files: 49 files [01:20,  1.90s/ files]
#
#
# Copying files: 50 files [01:21,  1.65s/ files]
#
#
# Copying files: 51 files [01:24,  1.99s/ files]
#
#
# Copying files: 52 files [01:26,  1.89s/ files]
#
#
# Copying files: 53 files [01:27,  1.71s/ files]
#
#
# Copying files: 54 files [01:29,  1.92s/ files]
#
#
# Copying files: 55 files [01:31,  1.93s/ files]
#
#
# Copying files: 56 files [01:33,  1.78s/ files]
#
#
# Copying files: 57 files [01:35,  1.98s/ files]
#
#
# Copying files: 58 files [01:37,  1.99s/ files]
#
#
# Copying files: 59 files [01:39,  1.88s/ files]
#
#
# Copying files: 60 files [01:41,  1.86s/ files]
#
#
# Copying files: 61 files [01:43,  1.83s/ files]
#
#
# Copying files: 62 files [01:44,  1.81s/ files]
#
#
# Copying files: 63 files [01:46,  1.83s/ files]
#
#
# Copying files: 64 files [01:48,  1.76s/ files]
#
#
# Copying files: 65 files [01:49,  1.72s/ files]
#
#
# Copying files: 66 files [01:51,  1.71s/ files]
#
#
# Copying files: 67 files [01:53,  1.78s/ files]
#
#
# Copying files: 68 files [01:55,  1.98s/ files]
#
#
# Copying files: 69 files [01:58,  2.09s/ files]
#
#
# Copying files: 70 files [02:00,  2.05s/ files]
#
#
# Copying files: 71 files [02:02,  2.19s/ files]
#
#
# Copying files: 72 files [02:04,  2.02s/ files]
#
#
# Copying files: 73 files [02:05,  1.82s/ files]
#
#
# Copying files: 74 files [02:07,  1.70s/ files]
#
#
# Copying files: 75 files [02:09,  1.79s/ files]
#
#
# Copying files: 76 files [02:11,  1.84s/ files]
#
#
# Copying files: 77 files [02:12,  1.78s/ files]
#
#
# Copying files: 78 files [02:14,  1.82s/ files]
#
#
# Copying files: 79 files [02:16,  1.79s/ files]
#
#
# Copying files: 80 files [02:18,  1.86s/ files]
#
#
# Copying files: 81 files [02:20,  1.88s/ files]
#
#
# Copying files: 82 files [02:22,  1.85s/ files]
#
#
# Copying files: 83 files [02:23,  1.55s/ files]
#
#
# Copying files: 84 files [02:24,  1.68s/ files]
#
#
# Copying files: 85 files [02:26,  1.69s/ files]
#
#
# Copying files: 86 files [02:28,  1.81s/ files]
#
#
# Copying files: 87 files [02:30,  1.76s/ files]
#
#
# Copying files: 88 files [02:31,  1.66s/ files]
#
#
# Copying files: 89 files [02:33,  1.78s/ files]
#
#
# Copying files: 90 files [02:35,  1.76s/ files]
#
#
# Copying files: 91 files [02:37,  1.71s/ files]
#
#
# Copying files: 92 files [02:38,  1.59s/ files]
#
#
# Copying files: 93 files [02:40,  1.63s/ files]
#
#
# Copying files: 94 files [02:41,  1.50s/ files]
#
#
# Copying files: 95 files [02:43,  1.52s/ files]
#
#
# Copying files: 96 files [02:44,  1.44s/ files]
#
#
# Copying files: 97 files [02:45,  1.50s/ files]
#
#
# Copying files: 98 files [02:47,  1.49s/ files]
#
#
# Copying files: 99 files [02:48,  1.42s/ files]
#
#
# Copying files: 100 files [02:49,  1.35s/ files]
#
#
# Copying files: 101 files [02:52,  1.63s/ files]
#
#
# Copying files: 102 files [02:53,  1.61s/ files]
#
#
# Copying files: 103 files [02:55,  1.57s/ files]
#
#
# Copying files: 104 files [02:57,  1.73s/ files]
#
#
# Copying files: 105 files [02:58,  1.59s/ files]
#
#
# Copying files: 106 files [03:00,  1.57s/ files]
#
#
# Copying files: 107 files [03:01,  1.52s/ files]
#
#
# Copying files: 108 files [03:02,  1.47s/ files]
#
#
# Copying files: 109 files [03:04,  1.48s/ files]
#
#
# Copying files: 110 files [03:05,  1.52s/ files]
#
#
# Copying files: 111 files [03:06,  1.38s/ files]
#
#
# Copying files: 112 files [03:08,  1.46s/ files]
#
#
# Copying files: 113 files [03:09,  1.43s/ files]
#
#
# Copying files: 114 files [03:11,  1.55s/ files]
#
#
# Copying files: 115 files [03:13,  1.74s/ files]
#
#
# Copying files: 116 files [03:15,  1.62s/ files]
#
#
# Copying files: 117 files [03:16,  1.54s/ files]
#
#
# Copying files: 118 files [03:18,  1.50s/ files]
#
#
# Copying files: 119 files [03:20,  1.66s/ files]
#
#
# Copying files: 120 files [03:21,  1.54s/ files]
#
#
# Copying files: 121 files [03:23,  1.59s/ files]
#
#
# Copying files: 122 files [03:24,  1.59s/ files]
#
#
# Copying files: 123 files [03:26,  1.62s/ files]
#
#
# Copying files: 124 files [03:27,  1.60s/ files]
#
#
# Copying files: 125 files [03:29,  1.56s/ files]
#
#
# Copying files: 126 files [03:31,  1.70s/ files]
#
#
# Copying files: 127 files [03:32,  1.44s/ files]
#
#
# Copying files: 128 files [03:33,  1.34s/ files]
#
#
# Copying files: 129 files [03:34,  1.43s/ files]
#
#
# Copying files: 130 files [03:37,  1.68s/ files]
#
#
# Copying files: 131 files [03:38,  1.59s/ files]
#
#
# Copying files: 132 files [03:39,  1.46s/ files]
#
#
# Copying files: 133 files [03:40,  1.32s/ files]
#
#
# Copying files: 134 files [03:42,  1.45s/ files]
#
#
# Copying files: 135 files [03:43,  1.39s/ files]
#
#
# Copying files: 136 files [03:45,  1.48s/ files]
#
#
# Copying files: 137 files [03:47,  1.59s/ files]
#
#
# Copying files: 138 files [03:48,  1.50s/ files]
#
#
# Copying files: 139 files [03:50,  1.54s/ files]
# Copying files: 140 files [03:51,  1.47s/ files]
#
#
# Copying files: 141 files [03:53,  1.69s/ files]
#
#
# Copying files: 142 files [03:55,  1.60s/ files]
#
#
# Copying files: 143 files [03:56,  1.57s/ files]
#
#
# Copying files: 144 files [03:58,  1.61s/ files]
#
#
# Copying files: 145 files [04:00,  1.73s/ files]
#
#
# Copying files: 146 files [04:01,  1.56s/ files]
#
#
# Copying files: 147 files [04:02,  1.45s/ files]
#
#
# Copying files: 148 files [04:04,  1.56s/ files]
#
#
# Copying files: 149 files [04:05,  1.45s/ files]
#
#
# Copying files: 150 files [04:06,  1.40s/ files]
#
#
# Copying files: 151 files [04:08,  1.48s/ files]
#
#
# Copying files: 152 files [04:10,  1.56s/ files]
#
#
# Copying files: 153 files [04:11,  1.55s/ files]
#
#
# Copying files: 154 files [04:13,  1.47s/ files]
#
#
# Copying files: 155 files [04:14,  1.50s/ files]
#
#
# Copying files: 156 files [04:16,  1.56s/ files]
#
#
# Copying files: 157 files [04:18,  1.56s/ files]
#
#
# Copying files: 158 files [04:20,  1.71s/ files]
#
#
# Copying files: 159 files [04:22,  1.77s/ files]
#
#
# Copying files: 160 files [04:23,  1.67s/ files]
#
#
# Copying files: 161 files [04:24,  1.57s/ files]
#
#
# Copying files: 162 files [04:26,  1.64s/ files]
#
#
# Copying files: 163 files [04:27,  1.54s/ files]
#
#
# Copying files: 164 files [04:29,  1.43s/ files]
#
#
# Copying files: 165 files [04:30,  1.53s/ files]
#
#
# Copying files: 166 files [04:32,  1.69s/ files]
#
#
# Copying files: 167 files [04:34,  1.64s/ files]
#
#
# Copying files: 168 files [04:35,  1.47s/ files]
#
#
# Copying files: 169 files [04:37,  1.58s/ files]
#
#
# Copying files: 170 files [04:38,  1.59s/ files]
#
#
# Copying files: 171 files [04:40,  1.53s/ files]
#
#
# Copying files: 172 files [04:41,  1.52s/ files]
#
#
# Copying files: 173 files [04:44,  1.77s/ files]
#
#
# Copying files: 174 files [04:45,  1.67s/ files]
#
#
# Copying files: 175 files [04:47,  1.63s/ files]
#
#
# Copying files: 176 files [04:48,  1.67s/ files]
#
#
# Copying files: 177 files [04:50,  1.69s/ files]
#
#
# Copying files: 178 files [04:51,  1.51s/ files]
#
#
# Copying files: 179 files [04:52,  1.38s/ files]
#
#
# Copying files: 180 files [04:54,  1.54s/ files]
#
#
# Copying files: 181 files [04:56,  1.49s/ files]
#
#
# Copying files: 182 files [04:57,  1.52s/ files]
#
#
# Copying files: 183 files [05:00,  1.78s/ files]
#
#
# Copying files: 184 files [05:01,  1.74s/ files]
#
#
# Copying files: 185 files [05:03,  1.72s/ files]
#
#
# Copying files: 186 files [05:04,  1.65s/ files]
#
#
# Copying files: 187 files [05:06,  1.51s/ files]
#
#
# Copying files: 188 files [05:07,  1.51s/ files]
#
#
# Copying files: 189 files [05:08,  1.46s/ files]
#
#
# Copying files: 190 files [05:10,  1.57s/ files]
#
#
# Copying files: 191 files [05:12,  1.55s/ files]
#
#
# Copying files: 192 files [05:13,  1.45s/ files]
#
#
# Copying files: 193 files [05:14,  1.42s/ files]
#
#
# Copying files: 194 files [05:17,  1.65s/ files]
#
#
# Copying files: 195 files [05:18,  1.50s/ files]
#
#
# Copying files: 196 files [05:19,  1.56s/ files]
#
#
# Copying files: 197 files [05:22,  1.75s/ files]
#
#
# Copying files: 198 files [05:23,  1.68s/ files]
#
#
# Copying files: 199 files [05:25,  1.61s/ files]
#
#
# Copying files: 200 files [05:26,  1.60s/ files]
#
#
# Copying files: 201 files [05:29,  2.01s/ files]
#
#
# Copying files: 202 files [05:31,  1.85s/ files]
#
#
# Copying files: 203 files [05:32,  1.60s/ files]
#
#
# Copying files: 204 files [05:33,  1.65s/ files]
#
#
# Copying files: 205 files [05:35,  1.70s/ files]
#
#
# Copying files: 206 files [05:37,  1.67s/ files]
#
#
# Copying files: 207 files [05:38,  1.45s/ files]
#
#
# Copying files: 208 files [05:40,  1.68s/ files]
#
#
# Copying files: 209 files [05:41,  1.61s/ files]
#
#
# Copying files: 210 files [05:44,  1.77s/ files]
#
#
# Copying files: 211 files [05:46,  2.07s/ files]
#
#
# Copying files: 212 files [05:48,  1.86s/ files]
#
#
# Copying files: 213 files [05:49,  1.75s/ files]
#
#
# Copying files: 214 files [05:51,  1.81s/ files]
#
#
# Copying files: 215 files [05:52,  1.60s/ files]
#
#
# Copying files: 216 files [05:53,  1.45s/ files]
#
#
# Copying files: 217 files [05:56,  1.74s/ files]
#
#
# Copying files: 218 files [05:57,  1.61s/ files]
#
#
# Copying files: 219 files [05:58,  1.55s/ files]
#
#
# Copying files: 220 files [06:00,  1.61s/ files]
#
#
# Copying files: 221 files [06:02,  1.56s/ files]
#
#
# Copying files: 222 files [06:03,  1.51s/ files]
#
#
# Copying files: 223 files [06:04,  1.44s/ files]
#
#
# Copying files: 224 files [06:06,  1.66s/ files]
#
#
# Copying files: 225 files [06:08,  1.59s/ files]
#
#
# Copying files: 226 files [06:09,  1.45s/ files]
#
#
# Copying files: 227 files [06:11,  1.59s/ files]
#
#
# Copying files: 228 files [06:12,  1.56s/ files]
#
#
# Copying files: 229 files [06:14,  1.57s/ files]
#
#
# Copying files: 230 files [06:15,  1.52s/ files]
#
#
# Copying files: 231 files [06:18,  1.70s/ files]
#
#
# Copying files: 232 files [06:19,  1.59s/ files]
#
#
# Copying files: 233 files [06:20,  1.56s/ files]
#
#
# Copying files: 234 files [06:22,  1.70s/ files]
#
#
# Copying files: 235 files [06:24,  1.54s/ files]
#
#
# Copying files: 236 files [06:25,  1.49s/ files]
#
#
# Copying files: 237 files [06:26,  1.46s/ files]
#
#
# Copying files: 238 files [06:28,  1.57s/ files]
#
#
# Copying files: 239 files [06:29,  1.42s/ files]
#
#
# Copying files: 240 files [06:31,  1.45s/ files]
#
#
# Copying files: 241 files [06:32,  1.50s/ files]
#
#
# Copying files: 242 files [06:34,  1.64s/ files]
#
#
# Copying files: 243 files [06:36,  1.64s/ files]
#
#
# Copying files: 244 files [06:37,  1.53s/ files]
#
#
# Copying files: 245 files [06:39,  1.68s/ files]
#
#
# Copying files: 246 files [06:41,  1.67s/ files]
#
#
# Copying files: 247 files [06:42,  1.57s/ files]
#
#
# Copying files: 248 files [06:43,  1.44s/ files]
#
#
# Copying files: 249 files [06:46,  1.66s/ files]
#
#
# Copying files: 250 files [06:47,  1.58s/ files]
#
#
# Copying files: 251 files [06:48,  1.48s/ files]
#
#
# Copying files: 252 files [06:50,  1.44s/ files]
#
#
# Copying files: 253 files [06:51,  1.49s/ files]
#
#
# Copying files: 254 files [06:53,  1.56s/ files]
#
#
# Copying files: 255 files [06:55,  1.62s/ files]
#
#
# Copying files: 256 files [06:56,  1.56s/ files]
#
#
# Copying files: 257 files [06:57,  1.45s/ files]
#
#
# Copying files: 258 files [06:59,  1.43s/ files]
#
#
# Copying files: 259 files [07:01,  1.63s/ files]
#
#
# Copying files: 260 files [07:02,  1.65s/ files]
#
#
# Copying files: 261 files [07:04,  1.62s/ files]
#
#
# Copying files: 262 files [07:06,  1.85s/ files]
#
#
# Copying files: 263 files [07:08,  1.74s/ files]
#
#
# Copying files: 264 files [07:09,  1.53s/ files]
#
#
# Copying files: 265 files [07:10,  1.52s/ files]
#
#
# Copying files: 266 files [07:12,  1.61s/ files]
#
#
# Copying files: 267 files [07:14,  1.59s/ files]
#
#
# Copying files: 268 files [07:15,  1.51s/ files]
#
#
# Copying files: 269 files [07:17,  1.76s/ files]
#
#
# Copying files: 270 files [07:19,  1.63s/ files]
#
#
# Copying files: 271 files [07:20,  1.59s/ files]
#
#
# Copying files: 272 files [07:22,  1.61s/ files]
#
#
# Copying files: 273 files [07:23,  1.49s/ files]
#
#
# Copying files: 274 files [07:25,  1.46s/ files]
#
#
# Copying files: 275 files [07:26,  1.40s/ files]
#
#
# Copying files: 276 files [07:28,  1.68s/ files]
#
#
# Copying files: 277 files [07:30,  1.71s/ files]
# Copying files: 278 files [07:31,  1.61s/ files]
#
#
# Copying files: 279 files [07:34,  1.83s/ files]
#
#
# Copying files: 280 files [07:34,  1.54s/ files]
#
#
# Copying files: 281 files [07:36,  1.40s/ files]
#
#
# Copying files: 282 files [07:38,  1.56s/ files]
#
#
# Copying files: 283 files [07:39,  1.67s/ files]
#
#
# Copying files: 284 files [07:41,  1.60s/ files]
#
#
# Copying files: 285 files [07:42,  1.49s/ files]
#
#
# Copying files: 286 files [07:43,  1.46s/ files]
#
#
# Copying files: 287 files [07:46,  1.67s/ files]
#
#
# Copying files: 288 files [07:47,  1.68s/ files]
#
#
# Copying files: 289 files [07:49,  1.60s/ files]
#
#
# Copying files: 290 files [07:50,  1.60s/ files]
#
#
# Copying files: 291 files [07:52,  1.68s/ files]
#
#
# Copying files: 292 files [07:53,  1.47s/ files]
#
#
# Copying files: 293 files [07:54,  1.37s/ files]
#
#
# Copying files: 294 files [07:57,  1.71s/ files]
#
#
# Copying files: 295 files [07:58,  1.61s/ files]
#
#
# Copying files: 296 files [08:00,  1.54s/ files]
#
#
# Copying files: 297 files [08:01,  1.56s/ files]
#
#
# Copying files: 298 files [08:03,  1.54s/ files]
#
#
# Copying files: 299 files [08:04,  1.55s/ files]
#
#
# Copying files: 300 files [08:06,  1.56s/ files]
#
#
# Copying files: 301 files [08:08,  1.62s/ files]
#
#
# Copying files: 302 files [08:09,  1.48s/ files]
#
#
# Copying files: 303 files [08:10,  1.55s/ files]
#
#
# Copying files: 304 files [08:12,  1.53s/ files]
#
#
# Copying files: 305 files [08:14,  1.58s/ files]
#
#
# Copying files: 306 files [08:15,  1.59s/ files]
#
#
# Copying files: 307 files [08:17,  1.71s/ files]
#
#
# Copying files: 308 files [08:19,  1.73s/ files]
#
#
# Copying files: 309 files [08:21,  1.69s/ files]
#
#
# Copying files: 310 files [08:22,  1.60s/ files]
#
#
# Copying files: 311 files [08:24,  1.79s/ files]
#
#
# Copying files: 312 files [08:26,  1.68s/ files]
#
#
# Copying files: 313 files [08:28,  1.75s/ files]
#
#
# Copying files: 314 files [08:29,  1.62s/ files]
#
#
# Copying files: 315 files [08:30,  1.60s/ files]
#
#
# Copying files: 316 files [08:32,  1.59s/ files]
#
#
# Copying files: 317 files [08:34,  1.60s/ files]
#
#
# Copying files: 318 files [08:35,  1.47s/ files]
#
#
# Copying files: 319 files [08:37,  1.61s/ files]
#
#
# Copying files: 320 files [08:39,  1.77s/ files]
#
#
# Copying files: 321 files [08:41,  1.72s/ files]
#
#
# Copying files: 322 files [08:42,  1.54s/ files]
#
#
# Copying files: 323 files [08:43,  1.62s/ files]
#
#
# Copying files: 324 files [08:46,  1.94s/ files]
#
#
# Copying files: 325 files [08:47,  1.63s/ files]
#
#
# Copying files: 326 files [08:49,  1.67s/ files]
#
#
# Copying files: 327 files [08:50,  1.65s/ files]
#
#
# Copying files: 328 files [08:52,  1.59s/ files]
#
#
# Copying files: 329 files [08:54,  1.61s/ files]
#
#
# Copying files: 330 files [08:55,  1.58s/ files]
#
#
# Copying files: 331 files [08:57,  1.66s/ files]
#
#
# Copying files: 332 files [08:58,  1.62s/ files]
#
#
# Copying files: 333 files [09:00,  1.58s/ files]
#
#
# Copying files: 334 files [09:01,  1.53s/ files]
#
#
# Copying files: 335 files [09:03,  1.54s/ files]
#
#
# Copying files: 336 files [09:05,  1.61s/ files]
#
#
# Copying files: 337 files [09:07,  1.71s/ files]
#
#
# Copying files: 338 files [09:08,  1.50s/ files]
#
#
# Copying files: 339 files [09:09,  1.59s/ files]
#
#
# Copying files: 340 files [09:11,  1.47s/ files]
#
#
# Copying files: 341 files [09:13,  1.63s/ files]
#
#
# Copying files: 342 files [09:14,  1.63s/ files]
#
#
# Copying files: 343 files [09:16,  1.64s/ files]
#
#
# Copying files: 344 files [09:18,  1.80s/ files]
#
#
# Copying files: 345 files [09:20,  1.73s/ files]
#
#
# Copying files: 346 files [09:21,  1.53s/ files]
#
#
# Copying files: 347 files [09:22,  1.54s/ files]
#
#
# Copying files: 348 files [09:23,  1.34s/ files]
#
#
# Copying files: 349 files [09:24,  1.20s/ files]
#
#
# Copying files: 350 files [09:25,  1.20s/ files]
#
#
# Copying files: 351 files [09:26,  1.12s/ files]
#
#
# Copying files: 352 files [09:27,  1.16s/ files]
#
#
# Copying files: 353 files [09:28,  1.14s/ files]
#
#
# Copying files: 354 files [09:30,  1.13s/ files]
#
#
# Copying files: 355 files [09:30,  1.01s/ files]
#
#
# Copying files: 356 files [09:31,  1.01 files/s]
#
#
# Copying files: 357 files [09:33,  1.14s/ files]
#
#
# Copying files: 358 files [09:34,  1.14s/ files]
#
#
# Copying files: 359 files [09:35,  1.15s/ files]
#
#
# Copying files: 360 files [09:36,  1.19s/ files]
#
#
# Copying files: 361 files [09:37,  1.11s/ files]
#
#
# Copying files: 362 files [09:39,  1.29s/ files]
#
#
# Copying files: 363 files [09:40,  1.12s/ files]
#
#
# Copying files: 364 files [09:41,  1.13s/ files]
#
#
# Copying files: 365 files [09:42,  1.09s/ files]
#
#
# Copying files: 366 files [09:43,  1.03s/ files]
#
#
# Copying files: 367 files [09:44,  1.05s/ files]
#
#
# Copying files: 368 files [09:45,  1.02s/ files]
#
#
# Copying files: 369 files [09:46,  1.02 files/s]
#
#
# Copying files: 370 files [09:46,  1.10 files/s]
#
#
# Copying files: 371 files [09:48,  1.01 files/s]
#
#
# Copying files: 372 files [09:49,  1.09s/ files]
#
#
# Copying files: 373 files [09:50,  1.15s/ files]
#
#
# Copying files: 374 files [09:51,  1.11s/ files]
#
#
# Copying files: 375 files [09:52,  1.01s/ files]
#
#
# Copying files: 376 files [09:53,  1.01s/ files]
#
#
# Copying files: 377 files [09:54,  1.11s/ files]
#
#
# Copying files: 378 files [09:56,  1.21s/ files]
#
#
# Copying files: 379 files [09:57,  1.22s/ files]
#
#
# Copying files: 380 files [09:58,  1.19s/ files]
#
#
# Copying files: 381 files [09:59,  1.13s/ files]
#
#
# Copying files: 382 files [10:01,  1.27s/ files]
#
#
# Copying files: 383 files [10:01,  1.08s/ files]
#
#
# Copying files: 384 files [10:03,  1.11s/ files]
#
#
# Copying files: 385 files [10:04,  1.11s/ files]
#
#
# Copying files: 386 files [10:05,  1.06s/ files]
#
#
# Copying files: 387 files [10:06,  1.09s/ files]
#
#
# Copying files: 388 files [10:07,  1.03s/ files]
#
#
# Copying files: 389 files [10:08,  1.06s/ files]
#
#
# Copying files: 390 files [10:08,  1.13 files/s]
#
#
# Copying files: 391 files [10:09,  1.02 files/s]
#
#
# Copying files: 392 files [10:11,  1.04s/ files]
#
#
# Copying files: 393 files [10:12,  1.20s/ files]
#
#
# Copying files: 394 files [10:14,  1.31s/ files]
#
#
# Copying files: 395 files [10:15,  1.24s/ files]
#
#
# Copying files: 396 files [10:16,  1.14s/ files]
#
#
# Copying files: 397 files [10:17,  1.13s/ files]
#
#
# Copying files: 398 files [10:18,  1.07s/ files]
#
#
# Copying files: 399 files [10:19,  1.11s/ files]
#
#
# Copying files: 400 files [10:20,  1.13s/ files]
#
#
# Copying files: 401 files [10:21,  1.08s/ files]
#
#
# Copying files: 402 files [10:22,  1.05 files/s]
#
#
# Copying files: 403 files [10:24,  1.23s/ files]
#
#
# Copying files: 404 files [10:24,  1.08s/ files]
#
#
# Copying files: 405 files [10:25,  1.08s/ files]
#
#
# Copying files: 406 files [10:26,  1.02s/ files]
#
#
# Copying files: 407 files [10:27,  1.03s/ files]
#
#
# Copying files: 408 files [10:29,  1.12s/ files]
#
#
# Copying files: 409 files [10:30,  1.13s/ files]
#
#
# Copying files: 410 files [10:31,  1.17s/ files]
#
#
# Copying files: 411 files [10:32,  1.12s/ files]
#
#
# Copying files: 412 files [10:34,  1.23s/ files]
#
#
# Copying files: 413 files [10:35,  1.21s/ files]
#
#
# Copying files: 414 files [10:36,  1.12s/ files]
#
#
# Copying files: 415 files [10:37,  1.07s/ files]
# Copying files: 416 files [10:38,  1.03s/ files]
#
#
# Copying files: 417 files [10:39,  1.10s/ files]
#
#
# Copying files: 418 files [10:40,  1.10s/ files]
#
#
# Copying files: 419 files [10:41,  1.09s/ files]
#
#
# Copying files: 420 files [10:42,  1.04s/ files]
#
#
# Copying files: 421 files [10:43,  1.14s/ files]
#
#
# Copying files: 422 files [10:45,  1.17s/ files]
#
#
# Copying files: 423 files [10:46,  1.19s/ files]
#
#
# Copying files: 424 files [10:47,  1.10s/ files]
#
#
# Copying files: 425 files [10:48,  1.05s/ files]
#
#
# Copying files: 426 files [10:49,  1.04s/ files]
#
#
# Copying files: 427 files [10:50,  1.16s/ files]
#
#
# Copying files: 428 files [10:51,  1.23s/ files]
#
#
# Copying files: 429 files [10:52,  1.13s/ files]
#
#
# Copying files: 430 files [10:53,  1.09s/ files]
#
#
# Copying files: 431 files [10:54,  1.08s/ files]
#
#
# Copying files: 432 files [10:56,  1.12s/ files]
#
#
# Copying files: 433 files [10:57,  1.17s/ files]
#
#
# Copying files: 434 files [10:58,  1.02s/ files]
#
#
# Copying files: 435 files [10:58,  1.02 files/s]
#
#
# Copying files: 436 files [11:00,  1.04s/ files]
#
#
# Copying files: 437 files [11:01,  1.04s/ files]
#
#
# Copying files: 438 files [11:02,  1.18s/ files]
#
#
# Copying files: 439 files [11:03,  1.01s/ files]
#
#
# Copying files: 440 files [11:04,  1.04s/ files]
#
#
# Copying files: 441 files [11:05,  1.06s/ files]
#
#
# Copying files: 442 files [11:06,  1.00s/ files]
#
#
# Copying files: 443 files [11:07,  1.10s/ files]
#
#
# Copying files: 444 files [11:08,  1.07s/ files]
#
#
# Copying files: 445 files [11:09,  1.08s/ files]
#
#
# Copying files: 446 files [11:11,  1.15s/ files]
#
#
# Copying files: 447 files [11:11,  1.03s/ files]
#
#
# Copying files: 448 files [11:12,  1.02s/ files]
#
#
# Copying files: 449 files [11:14,  1.12s/ files]
#
#
# Copying files: 450 files [11:15,  1.12s/ files]
#
#
# Copying files: 451 files [11:16,  1.15s/ files]
#
#
# Copying files: 452 files [11:17,  1.10s/ files]
#
#
# Copying files: 453 files [11:18,  1.12s/ files]
#
#
# Copying files: 454 files [11:19,  1.07s/ files]
#
#
# Copying files: 455 files [11:20,  1.04s/ files]
#
#
# Copying files: 456 files [11:21,  1.02s/ files]
#
#
# Copying files: 457 files [11:22,  1.00s/ files]
#
#
# Copying files: 458 files [11:24,  1.14s/ files]
#
#
# Copying files: 459 files [11:24,  1.07s/ files]
#
#
# Copying files: 460 files [11:26,  1.07s/ files]
#
#
# Copying files: 461 files [11:26,  1.01s/ files]
#
#
# Copying files: 462 files [11:27,  1.02 files/s]
#
#
# Copying files: 463 files [11:29,  1.06s/ files]
#
#
# Copying files: 464 files [11:30,  1.15s/ files]
#
#
# Copying files: 465 files [11:31,  1.16s/ files]
#
#
# Copying files: 466 files [11:32,  1.07s/ files]
#
#
# Copying files: 467 files [11:33,  1.02 files/s]
#
#
# Copying files: 468 files [11:34,  1.04s/ files]
#
#
# Copying files: 469 files [11:35,  1.13s/ files]
#
#
# Copying files: 470 files [11:36,  1.11s/ files]
#
#
# Copying files: 471 files [11:37,  1.01s/ files]
#
#
# Copying files: 472 files [11:38,  1.02 files/s]
#
#
# Copying files: 473 files [11:39,  1.05s/ files]
#
#
# Copying files: 474 files [11:40,  1.05s/ files]
#
#
# Copying files: 475 files [11:42,  1.26s/ files]
#
#
# Copying files: 476 files [11:43,  1.13s/ files]
#
#
# Copying files: 477 files [11:44,  1.08s/ files]
#
#
# Copying files: 478 files [11:45,  1.09s/ files]
#
#
# Copying files: 479 files [11:46,  1.17s/ files]
#
#
# Copying files: 480 files [11:47,  1.16s/ files]
#
#
# Copying files: 481 files [11:48,  1.09s/ files]
#
#
# Copying files: 482 files [11:49,  1.02 files/s]
#
#
# Copying files: 483 files [11:50,  1.02s/ files]
#
#
# Copying files: 484 files [11:51,  1.07s/ files]
#
#
# Copying files: 485 files [11:53,  1.14s/ files]
#
#
# Copying files: 486 files [11:53,  1.05s/ files]
#
#
# Copying files: 487 files [11:54,  1.02s/ files]
#
#
# Copying files: 488 files [11:56,  1.08s/ files]
#
#
# Copying files: 489 files [11:57,  1.14s/ files]
#
#
# Copying files: 490 files [11:58,  1.23s/ files]
#
#
# Copying files: 491 files [11:59,  1.17s/ files]
#
#
# Copying files: 492 files [12:01,  1.15s/ files]
#
#
# Copying files: 493 files [12:01,  1.05s/ files]
#
#
# Copying files: 494 files [12:03,  1.26s/ files]
#
#
# Copying files: 495 files [12:04,  1.13s/ files]
#
#
# Copying files: 496 files [12:05,  1.06s/ files]
#
#
# Copying files: 497 files [12:06,  1.08s/ files]
#
#
# Copying files: 498 files [12:07,  1.02s/ files]
#
#
# Copying files: 499 files [12:08,  1.12s/ files]
#
#
# Copying files: 500 files [12:09,  1.14s/ files]
#
#
# Copying files: 501 files [12:10,  1.07s/ files]
#
#
# Copying files: 502 files [12:11,  1.00 files/s]
#
#
# Copying files: 503 files [12:12,  1.03s/ files]
#
#
# Copying files: 504 files [12:14,  1.13s/ files]
#
#
# Copying files: 505 files [12:15,  1.15s/ files]
#
#
# Copying files: 506 files [12:16,  1.21s/ files]
#
#
# Copying files: 507 files [12:17,  1.17s/ files]
#
#
# Copying files: 508 files [12:18,  1.11s/ files]
#
#
# Copying files: 509 files [12:19,  1.12s/ files]
#
#
# Copying files: 510 files [12:20,  1.07s/ files]
#
#
# Copying files: 511 files [12:21,  1.11s/ files]
#
#
# Copying files: 512 files [12:22,  1.00 files/s]
#
#
# Copying files: 513 files [12:23,  1.04 files/s]
#
#
# Copying files: 514 files [12:25,  1.12s/ files]
#
#
# Copying files: 515 files [12:26,  1.11s/ files]
#
#
# Copying files: 516 files [12:27,  1.13s/ files]
#
#
# Copying files: 517 files [12:27,  1.08 files/s]
#
#
# Copying files: 518 files [12:28,  1.01s/ files]
#
#
# Copying files: 519 files [12:30,  1.10s/ files]
#
#
# Copying files: 520 files [12:31,  1.10s/ files]
#
#
# Copying files: 521 files [12:32,  1.16s/ files]
#
#
# Copying files: 522 files [12:33,  1.09s/ files]
#
#
# Copying files: 523 files [12:34,  1.07s/ files]
#
#
# Copying files: 524 files [12:36,  1.30s/ files]
#
#
# Copying files: 525 files [12:37,  1.17s/ files]
#
#
# Copying files: 526 files [12:38,  1.13s/ files]
#
#
# Copying files: 527 files [12:39,  1.09s/ files]
#
#
# Copying files: 528 files [12:39,  1.07 files/s]
#
#
# Copying files: 529 files [12:41,  1.05s/ files]
#
#
# Copying files: 530 files [12:42,  1.10s/ files]
#
#
# Copying files: 531 files [12:43,  1.04s/ files]
#
#
# Copying files: 532 files [12:44,  1.07 files/s]
#
#
# Copying files: 533 files [12:45,  1.01s/ files]
#
#
# Copying files: 534 files [12:46,  1.11s/ files]
#
#
# Copying files: 535 files [12:47,  1.19s/ files]
#
#
# Copying files: 536 files [12:49,  1.15s/ files]
#
#
# Copying files: 537 files [12:49,  1.06 files/s]
#
#
# Copying files: 538 files [12:50,  1.02s/ files]
#
#
# Copying files: 539 files [12:51,  1.09s/ files]
#
#
# Copying files: 540 files [12:53,  1.16s/ files]
#
#
# Copying files: 541 files [12:54,  1.09s/ files]
#
#
# Copying files: 542 files [12:54,  1.01 files/s]
#
#
# Copying files: 543 files [12:56,  1.11s/ files]
#
#
# Copying files: 544 files [12:57,  1.17s/ files]
#
#
# Copying files: 545 files [12:58,  1.16s/ files]
#
#
# Copying files: 546 files [13:00,  1.18s/ files]
#
#
# Copying files: 547 files [13:00,  1.03s/ files]
#
#
# Copying files: 548 files [13:01,  1.01s/ files]
#
#
# Copying files: 549 files [13:03,  1.17s/ files]
#
#
# Copying files: 550 files [13:04,  1.16s/ files]
#
#
# Copying files: 551 files [13:05,  1.12s/ files]
#
#
# Copying files: 552 files [13:06,  1.05s/ files]
#
#
# Copying files: 553 files [13:07,  1.14s/ files]
# Copying files: 554 files [13:08,  1.09s/ files]
#
#
# Copying files: 555 files [13:09,  1.13s/ files]
#
#
# Copying files: 556 files [13:10,  1.12s/ files]
#
#
# Copying files: 557 files [13:11,  1.03s/ files]
#
#
# Copying files: 558 files [13:13,  1.11s/ files]
#
#
# Copying files: 559 files [13:13,  1.07s/ files]
#
#
# Copying files: 560 files [13:15,  1.09s/ files]
#
#
# Copying files: 561 files [13:15,  1.01s/ files]
#
#
# Copying files: 562 files [13:16,  1.07 files/s]
#
#
# Copying files: 563 files [13:18,  1.15s/ files]
#
#
# Copying files: 564 files [13:19,  1.11s/ files]
#
#
# Copying files: 565 files [13:20,  1.12s/ files]
#
#
# Copying files: 566 files [13:21,  1.09s/ files]
#
#
# Copying files: 567 files [13:22,  1.05 files/s]
#
#
# Copying files: 568 files [13:23,  1.02 files/s]
#
#
# Copying files: 569 files [13:24,  1.08s/ files]
#
#
# Copying files: 570 files [13:25,  1.03 files/s]
#
#
# Copying files: 571 files [13:26,  1.02 files/s]
#
#
# Copying files: 572 files [13:27,  1.16s/ files]
#
#
# Copying files: 573 files [13:29,  1.27s/ files]
#
#
# Copying files: 574 files [13:30,  1.15s/ files]
#
#
# Copying files: 575 files [13:31,  1.11s/ files]
#
#
# Copying files: 576 files [13:32,  1.00s/ files]
#
#
# Copying files: 577 files [13:32,  1.03 files/s]
#
#
# Copying files: 578 files [13:34,  1.05s/ files]
#
#
# Copying files: 579 files [13:35,  1.21s/ files]
#
#
# Copying files: 580 files [13:36,  1.15s/ files]
#
#
# Copying files: 581 files [13:37,  1.01 files/s]
#
#
# Copying files: 582 files [13:38,  1.03s/ files]
#
#
# Copying files: 583 files [13:39,  1.03s/ files]
#
#
# Copying files: 584 files [13:40,  1.13s/ files]
#
#
# Copying files: 585 files [13:42,  1.14s/ files]
#
#
# Copying files: 586 files [13:42,  1.07s/ files]
#
#
# Copying files: 587 files [13:44,  1.07s/ files]
#
#
# Copying files: 588 files [13:45,  1.10s/ files]
#
#
# Copying files: 589 files [13:46,  1.10s/ files]
#
#
# Copying files: 590 files [13:47,  1.14s/ files]
#
#
# Copying files: 591 files [13:48,  1.05s/ files]
#
#
# Copying files: 592 files [13:49,  1.08s/ files]
#
#
# Copying files: 593 files [13:50,  1.10s/ files]
#
#
# Copying files: 594 files [13:51,  1.04s/ files]
#
#
# Copying files: 595 files [13:53,  1.18s/ files]
#
#
# Copying files: 596 files [13:53,  1.06s/ files]
#
#
# Copying files: 597 files [13:54,  1.04s/ files]
#
#
# Copying files: 598 files [13:55,  1.08s/ files]
#
#
# Copying files: 599 files [13:56,  1.03 files/s]
#
#
# Copying files: 600 files [13:57,  1.05s/ files]
#
#
# Copying files: 601 files [13:58,  1.02s/ files]
#
#
# Copying files: 602 files [13:59,  1.01 files/s]
#
#
# Copying files: 603 files [14:00,  1.04 files/s]
#
#
# Copying files: 604 files [14:01,  1.02 files/s]
#
#
# Copying files: 605 files [14:03,  1.11s/ files]
#
#
# Copying files: 606 files [14:04,  1.20s/ files]
#
#
# Copying files: 607 files [14:05,  1.17s/ files]
#
#
# Copying files: 608 files [14:06,  1.15s/ files]
#
#
# Copying files: 609 files [14:07,  1.02 files/s]
#
#
# Copying files: 610 files [14:08,  1.14s/ files]
#
#
# Copying files: 611 files [14:09,  1.09s/ files]
#
#
# Copying files: 612 files [14:10,  1.09s/ files]
#
#
# Copying files: 613 files [14:11,  1.04s/ files]
#
#
# Copying files: 614 files [14:12,  1.04 files/s]
#
#
# Copying files: 615 files [14:13,  1.00 files/s]
#
#
# Copying files: 616 files [14:15,  1.15s/ files]
#
#
# Copying files: 617 files [14:16,  1.07s/ files]
#
#
# Copying files: 618 files [14:16,  1.02s/ files]
#
#
# Copying files: 619 files [14:18,  1.03s/ files]
#
#
# Copying files: 620 files [14:19,  1.14s/ files]
#
#
# Copying files: 621 files [14:20,  1.18s/ files]
#
#
# Copying files: 622 files [14:21,  1.15s/ files]
#
#
# Copying files: 623 files [14:22,  1.01 files/s]
#
#
# Copying files: 624 files [14:23,  1.02 files/s]
#
#
# Copying files: 625 files [14:24,  1.00s/ files]
#
#
# Copying files: 626 files [14:25,  1.12s/ files]
#
#
# Copying files: 627 files [14:26,  1.10s/ files]
#
#
# Copying files: 628 files [14:27,  1.02s/ files]
#
#
# Copying files: 629 files [14:28,  1.07s/ files]
#
#
# Copying files: 630 files [14:29,  1.09s/ files]
#
#
# Copying files: 631 files [14:31,  1.09s/ files]
#
#
# Copying files: 632 files [14:32,  1.04s/ files]
#
#
# Copying files: 633 files [14:33,  1.05s/ files]
#
#
# Copying files: 634 files [14:34,  1.10s/ files]
#
#
# Copying files: 635 files [14:35,  1.12s/ files]
#
#
# Copying files: 636 files [14:37,  1.25s/ files]
#
#
# Copying files: 637 files [14:38,  1.17s/ files]
#
#
# Copying files: 638 files [14:39,  1.14s/ files]
#
#
# Copying files: 639 files [14:39,  1.03s/ files]
#
#
# Copying files: 640 files [14:41,  1.13s/ files]
#
#
# Copying files: 641 files [14:42,  1.09s/ files]
#
#
# Copying files: 642 files [14:43,  1.04s/ files]
#
#
# Copying files: 643 files [14:43,  1.05 files/s]
#
#
# Copying files: 644 files [14:44,  1.05 files/s]
#
#
# Copying files: 645 files [14:45,  1.00 files/s]
#
#
# Copying files: 646 files [14:47,  1.11s/ files]
#
#
# Copying files: 647 files [14:48,  1.02s/ files]
#
#
# Copying files: 648 files [14:49,  1.11s/ files]
#
#
# Copying files: 649 files [14:50,  1.06s/ files]
#
#
# Copying files: 650 files [14:51,  1.04s/ files]
#
#
# Copying files: 651 files [14:52,  1.05s/ files]
#
#
# Copying files: 652 files [14:53,  1.04s/ files]
#
#
# Copying files: 653 files [14:54,  1.14s/ files]
#
#
# Copying files: 654 files [14:56,  1.16s/ files]
#
#
# Copying files: 655 files [14:57,  1.11s/ files]
#
#
# Copying files: 656 files [14:58,  1.15s/ files]
#
#
# Copying files: 657 files [14:58,  1.01s/ files]
#
#
# Copying files: 658 files [15:00,  1.02s/ files]
#
#
# Copying files: 659 files [15:01,  1.04s/ files]
#
#
# Copying files: 660 files [15:01,  1.02 files/s]
#
#
# Copying files: 661 files [15:03,  1.05s/ files]
#
#
# Copying files: 662 files [15:04,  1.09s/ files]
#
#
# Copying files: 663 files [15:05,  1.09s/ files]
#
#
# Copying files: 664 files [15:06,  1.00s/ files]
#
#
# Copying files: 665 files [15:07,  1.02 files/s]
#
#
# Copying files: 666 files [15:08,  1.13s/ files]
#
#
# Copying files: 667 files [15:09,  1.12s/ files]
#
#
# Copying files: 668 files [15:10,  1.11s/ files]
#
#
# Copying files: 669 files [15:11,  1.01 files/s]
#
#
# Copying files: 670 files [15:12,  1.03s/ files]
#
#
# Copying files: 671 files [15:14,  1.14s/ files]
#
#
# Copying files: 672 files [15:15,  1.11s/ files]
#
#
# Copying files: 673 files [15:15,  1.04 files/s]
#
#
# Copying files: 674 files [15:16,  1.01 files/s]
#
#
# Copying files: 675 files [15:17,  1.06s/ files]
#
#
# Copying files: 676 files [15:19,  1.08s/ files]
#
#
# Copying files: 677 files [15:20,  1.19s/ files]
#
#
# Copying files: 678 files [15:21,  1.08s/ files]
#
#
# Copying files: 679 files [15:22,  1.00 files/s]
#
#
# Copying files: 680 files [15:23,  1.10s/ files]
#
#
# Copying files: 681 files [15:24,  1.14s/ files]
#
#
# Copying files: 682 files [15:25,  1.12s/ files]
#
#
# Copying files: 683 files [15:27,  1.18s/ files]
#
#
# Copying files: 684 files [15:27,  1.01s/ files]
#
#
# Copying files: 685 files [15:28,  1.04s/ files]
#
#
# Copying files: 686 files [15:30,  1.12s/ files]
#
#
# Copying files: 687 files [15:31,  1.19s/ files]
#
#
# Copying files: 688 files [15:33,  1.36s/ files]
